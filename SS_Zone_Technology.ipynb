# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'C:\Users\Deepak Raj\Desktop\Data_Science\Machine Learning\SS Zone\Data Cleaning and Preprocessing.csv')

# %%
df
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %% [markdown]
# ## Basic checks

# %%
df.shape
# Out:
# (324, 23)

# %%
#no of rows in the given dataset is 324
#no of columns in the given dataset is 23

# %%
#information about the given numerical data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Observation      324 non-null    object
#  1   Y-Kappa          324 non-null    float64
#  2   ChipRate         319 non-null    float64
#  3   BF-CMratio       307 non-null    float64
#  4   BlowFlow         308 non-null    float64
#  5   ChipLevel4       323 non-null    float64
#  6   T-upperExt-2     322 non-null    float64
#  7   T-lowerExt-2     322 non-null    float64
#  8   UCZAA            299 non-null    float64
#  9   WhiteFlow-4      323 non-null    float64
#  10  AAWhiteSt-4      173 non-null    float64
#  11  AA-Wood-4        323 non-null    float64
#  12  ChipMoisture-4   323 non-null    float64
#  13  SteamFlow-4      323 non-null    float64
#  14  Lower-HeatT-3    322 non-null    float64
#  15  Upper-HeatT-3    322 non-null    float64
# ...

# %%
#description about the data
df.describe()
# Out:
#           Y-Kappa    ChipRate  BF-CMratio     BlowFlow  ChipLevel4   \
# count  324.000000  319.000000  307.000000   308.000000   323.000000
# mean    20.635370   14.347937   87.464456  1237.837614   258.164483
# std      3.070036    1.499095    7.995012   100.593735    87.987452
# min     12.170000    9.983000   68.645000     0.000000     0.000000
# 25%     18.382500   13.358000   81.823000  1193.215250   213.527000
# 50%     20.845000   14.308000   86.739000  1273.138500   271.792000
# 75%     23.032500   15.517000   92.372000  1289.196000   321.680000
# max     27.600000   16.958000  121.717000  1351.240000   419.014000
#
#        T-upperExt-2   T-lowerExt-2         UCZAA  WhiteFlow-4   AAWhiteSt-4   \
# count     322.000000      322.000000  299.000000    323.000000    173.000000
# mean      356.904295      324.020180    1.492010    591.732260      6.140410
# std         9.209290        7.621402    0.105923     67.016351      0.081609
# ...

# %%
#information about the given categorical data
df.describe(include='O')
# Out:
#        Observation
# count          324
# unique         301
# top        9-22:00
# freq             2

# %% [markdown]
# ## Data Preprocessing

# %%
#drop symbol column
df.drop('Observation',axis=1,inplace=True)

# %%
#missing value check
df.isnull().sum()
# Out:
# Y-Kappa              0
# ChipRate             5
# BF-CMratio          17
# BlowFlow            16
# ChipLevel4           1
# T-upperExt-2         2
# T-lowerExt-2         2
# UCZAA               25
# WhiteFlow-4          1
# AAWhiteSt-4        151
# AA-Wood-4            1
# ChipMoisture-4       1
# SteamFlow-4          1
# Lower-HeatT-3        2
# Upper-HeatT-3        2
# ChipMass-4           1
# WeakLiquorF          1
# BlackFlow-2          2
# WeakWashF            1
# SteamHeatF-3         2
# T-Top-Chips-4        1
# SulphidityL-4      151
# dtype: int64

# %%
df
# Out:
#      Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# 0      23.10    16.520     121.717  1177.607      169.805        358.282
# 1      27.60    16.810      79.022  1328.360      341.327        351.050
# 2      23.19    16.709      79.562  1329.407      239.161        350.022
# 3      23.60    16.478      81.011  1334.877      213.527        350.938
# 4      22.90    15.618      93.244  1334.168      243.131        351.640
# ..       ...       ...         ...       ...          ...            ...
# 319    23.75    12.667      93.450  1178.252      276.955        347.286
# 320    19.80    12.558      94.352  1184.119      297.071        399.135
# 321    23.01    12.550      90.842  1188.517      289.826        373.633
# 322    24.32    13.083      88.910  1192.879      318.006        364.081
# 323    25.75    13.417      85.451  1186.342      248.312        356.289
#
#      T-lowerExt-2    UCZAA  WhiteFlow-4   AAWhiteSt-4   ...  SteamFlow-4   \
# ...

# %%
my_list = list(df)

# %%
my_list
# Out:
# ['Y-Kappa',
#  'ChipRate',
#  'BF-CMratio',
#  'BlowFlow',
#  'ChipLevel4 ',
#  'T-upperExt-2 ',
#  'T-lowerExt-2  ',
#  'UCZAA',
#  'WhiteFlow-4 ',
#  'AAWhiteSt-4 ',
#  'AA-Wood-4  ',
#  'ChipMoisture-4 ',
#  'SteamFlow-4 ',
#  'Lower-HeatT-3',
#  'Upper-HeatT-3 ',
#  'ChipMass-4 ',
#  'WeakLiquorF ',
#  'BlackFlow-2 ',
#  'WeakWashF ',
#  'SteamHeatF-3 ',
#  'T-Top-Chips-4 ',
#  'SulphidityL-4 ']

# %%
df.rename(columns={
    'Y-Kappa':'Y_Kappa',
    'BF-CMratio':'BF_CMratio',
    'ChipLevel4 ':'ChipLevel4',
    'T-upperExt-2 ':'T_upperExt_2',
    'T-lowerExt-2  ':'T_lowerExt_2',
    'WhiteFlow-4 ':'WhiteFlow_4',
    'AAWhiteSt-4 ':'AAWhiteSt_4',
    'AA-Wood-4  ':'AA_Wood_4',
    'ChipMoisture-4 ':'ChipMoisture_4',
    'SteamFlow-4 ':'SteamFlow_4',
    'Lower-HeatT-3':'Lower_HeatT_3',
    'Upper-HeatT-3 ':'Upper_HeatT_3',
    'ChipMass-4 ':'ChipMass_4',
    'WeakLiquorF ':'WeakLiquorF',
    'BlackFlow-2 ':'BlackFlow_2',
    'WeakWashF ':'WeakWashF',
    'SteamHeatF-3 ':'SteamHeatF_3',
    'T-Top-Chips-4 ':'T_Top_Chips_4',
    'SulphidityL-4 ':'SulphidityL_4',
},inplace = True)

# %%
changed_header = list(df)

# %%
changed_header
# Out:
# ['Y_Kappa',
#  'ChipRate',
#  'BF_CMratio',
#  'BlowFlow',
#  'ChipLevel4',
#  'T_upperExt_2',
#  'T_lowerExt_2',
#  'UCZAA',
#  'WhiteFlow_4',
#  'AAWhiteSt_4',
#  'AA_Wood_4',
#  'ChipMoisture_4',
#  'SteamFlow_4',
#  'Lower_HeatT_3',
#  'Upper_HeatT_3',
#  'ChipMass_4',
#  'WeakLiquorF',
#  'BlackFlow_2',
#  'WeakWashF',
#  'SteamHeatF_3',
#  'T_Top_Chips_4',
#  'SulphidityL_4']

# %%
#ChipRate null columns
df.loc[df['ChipRate'].isnull()==True,'ChipRate']=df.ChipRate.mean() #replace null column with mean values

# %%
#BF_CMratio null columns
df.loc[df['BF_CMratio'].isnull()==True,'BF_CMratio']=df.BF_CMratio.mean() #replace null column with mean values

# %%
#BlowFlow null columns
df.loc[df['BlowFlow'].isnull()==True,'BlowFlow']=df.BlowFlow.mean() #replace null column with mean values

# %%
#ChipLevel4 null columns
df.loc[df['ChipLevel4'].isnull()==True,'ChipLevel4']=df.ChipLevel4.mean() #replace null column with mean values

# %%
#T_upperExt_2 null columns
df.loc[df['T_upperExt_2'].isnull()==True,'T_upperExt_2']=df.T_upperExt_2.mean() #replace null column with mean values

# %%
#T_lowerExt_2 null columns
df.loc[df['T_lowerExt_2'].isnull()==True,'T_lowerExt_2']=df.T_lowerExt_2.mean() #replace null column with mean values

# %%
#UCZAA null columns
df.loc[df['UCZAA'].isnull()==True,'UCZAA']=df.UCZAA.mean() #replace null column with mean values

# %%
#WhiteFlow_4 null columns
df.loc[df['WhiteFlow_4'].isnull()==True,'WhiteFlow_4']=df.WhiteFlow_4.mean() #replace null column with mean values

# %%
#AAWhiteSt_4 null columns
df.loc[df['AAWhiteSt_4'].isnull()==True,'AAWhiteSt_4']=df.AAWhiteSt_4.mean() #replace null column with mean values

# %%
#AA-Wood-4 null columns
df.loc[df['AA_Wood_4'].isnull()==True,'AA_Wood_4']=df.AA_Wood_4.mean() #replace null column with mean values

# %%
#ChipMoisture_4 null columns
df.loc[df['ChipMoisture_4'].isnull()==True,'ChipMoisture_4']=df.ChipMoisture_4.mean() #replace null column with mean values

# %%
#SteamFlow_4 null columns
df.loc[df['SteamFlow_4'].isnull()==True,'SteamFlow_4']=df.SteamFlow_4.mean() #replace null column with mean values

# %%
#Lower_HeatT_3 null columns
df.loc[df['Lower_HeatT_3'].isnull()==True,'Lower_HeatT_3']=df.Lower_HeatT_3.mean() #replace null column with mean values

# %%
#Upper_HeatT_3 null columns
df.loc[df['Upper_HeatT_3'].isnull()==True,'Upper_HeatT_3']=df.Upper_HeatT_3.mean() #replace null column with mean values

# %%
#ChipMass_4 null columns
df.loc[df['ChipMass_4'].isnull()==True,'ChipMass_4']=df.ChipMass_4.mean() #replace null column with mean values

# %%
#WeakLiquorF null columns
df.loc[df['WeakLiquorF'].isnull()==True,'WeakLiquorF']=df.WeakLiquorF.mean() #replace null column with mean values

# %%
#BlackFlow_2 null columns
df.loc[df['BlackFlow_2'].isnull()==True,'BlackFlow_2']=df.BlackFlow_2.mean() #replace null column with mean values

# %%
#WeakWashF null columns
df.loc[df['WeakWashF'].isnull()==True,'WeakWashF']=df.WeakWashF.mean() #replace null column with mean values

# %%
#SteamHeatF_3 null columns
df.loc[df['SteamHeatF_3'].isnull()==True,'SteamHeatF_3']=df.SteamHeatF_3.mean() #replace null column with mean values

# %%
#T_Top_Chips_4 null columns
df.loc[df['T_Top_Chips_4'].isnull()==True,'T_Top_Chips_4']=df.T_Top_Chips_4.mean() #replace null column with mean values

# %%
#T_Top_Chips_4 null columns
df.loc[df['SulphidityL_4'].isnull()==True,'SulphidityL_4']=df.SulphidityL_4.mean() #replace null column with mean values

# %%
df.isnull().sum()
# Out:
# Y_Kappa           0
# ChipRate          0
# BF_CMratio        0
# BlowFlow          0
# ChipLevel4        0
# T_upperExt_2      0
# T_lowerExt_2      0
# UCZAA             0
# WhiteFlow_4       0
# AAWhiteSt_4       0
# AA_Wood_4         0
# ChipMoisture_4    0
# SteamFlow_4       0
# Lower_HeatT_3     0
# Upper_HeatT_3     0
# ChipMass_4        0
# WeakLiquorF       0
# BlackFlow_2       0
# WeakWashF         0
# SteamHeatF_3      0
# T_Top_Chips_4     0
# SulphidityL_4     0
# dtype: int64

# %%
#null values are replaced by mean value

# %%
#duplicate value
df.duplicated().sum()
# Out:
# 23

# %%
#remove duplicate values
df.drop_duplicates(inplace=True)

# %%
#duplicate value
df.duplicated().sum()
# Out:
# 0

# %%
#removed duplicated value
df
# Out:
#      Y_Kappa   ChipRate  BF_CMratio  BlowFlow  ChipLevel4  T_upperExt_2  \
# 0      23.10  16.520000     121.717  1177.607     169.805       358.282
# 1      27.60  16.810000      79.022  1328.360     341.327       351.050
# 2      23.19  16.709000      79.562  1329.407     239.161       350.022
# 3      23.60  16.478000      81.011  1334.877     213.527       350.938
# 4      22.90  15.618000      93.244  1334.168     243.131       351.640
# ..       ...        ...         ...       ...         ...           ...
# 298    20.90  15.167000      84.640  1283.706     339.440       354.803
# 299    24.98  14.347937      85.034  1278.345     368.564       357.723
# 300    21.00  14.347937      88.013  1307.722     278.842       357.438
# 301    21.40  14.347937      85.490  1255.986     273.484       361.365
# 307    20.89  14.308000      94.172  1327.832     251.120       351.263
#
#      T_lowerExt_2    UCZAA  WhiteFlow_4  AAWhiteSt_4  ...  SteamFlow_4  \
# ...

# %%
#outliers
box=df[['Y_Kappa',
 'ChipRate',
 'BF_CMratio',
 'BlowFlow',
 'ChipLevel4',
 'T_upperExt_2',
 'T_lowerExt_2',
 'UCZAA',
 'WhiteFlow_4',
 'AAWhiteSt_4',
 'AA_Wood_4',
 'ChipMoisture_4',
 'SteamFlow_4',
 'Lower_HeatT_3',
 'Upper_HeatT_3',
 'ChipMass_4',
 'WeakLiquorF',
 'BlackFlow_2',
 'WeakWashF',
 'SteamHeatF_3',
 'T_Top_Chips_4',
 'SulphidityL_4']]
plt.figure(figsize=(50,30), facecolor='white')#to sey canvas size
plotnumber = 1#counter

for column in box:#acc
    if plotnumber<=25 : # as there are 9 columns in the data
        ax = plt.subplot(25,1,plotnumber)#plotting 6 graphs
        sns.boxplot(x=box[column])#boxplot to check for outlier
        plt.xlabel(column,fontsize=10)#assign name to x-axis and set font-20
     
    plotnumber+=1#counter increment 
plt.tight_layout()#to show plot

# %%
df[(df.ChipRate<11)]
# Out:
#      Y_Kappa  ChipRate  BF_CMratio  BlowFlow  ChipLevel4  T_upperExt_2  \
# 36     12.81    10.942     114.567  1241.142     215.485       346.411
# 37     14.53    10.833      93.121  1202.818     339.119       342.535
# 283    20.37    10.967      99.982   998.153     302.251       344.295
# 284    20.20     9.983     102.237  1027.485     369.632       342.576
# 285    18.83    10.967      94.472  1036.043     314.321       340.338
# 288    22.10    10.933      97.752  1038.618     333.743       343.695
# 289    22.50    10.625      89.193  1010.855     322.470       342.637
#
#      T_lowerExt_2    UCZAA  WhiteFlow_4  AAWhiteSt_4  ...  SteamFlow_4  \
# 36        328.375  1.37800      654.744      6.14041  ...       70.261
# 37        324.194  1.25800      601.694      6.04900  ...       63.969
# 283       305.080  1.60400      471.537      6.26100  ...       57.260
# 284       298.560  1.63900      454.091      6.14041  ...       54.259
# ...

# %%
#replace ChipRate outliers with mean values
df.ChipRate[(df.ChipRate<11)]=df.ChipRate.mean()

# %%
df[(df.BF_CMratio>100)]
# Out:
#      Y_Kappa   ChipRate  BF_CMratio  BlowFlow  ChipLevel4  T_upperExt_2  \
# 0      23.10  16.520000     121.717  1177.607     169.805       358.282
# 19     20.00  12.983000     100.073  1206.709     191.648       349.412
# 35     12.17  12.667000     114.570  1253.584     188.043       350.765
# 36     12.81  14.338793     114.567  1241.142     215.485       346.411
# 117    17.43  13.250000     100.322  1301.675     241.529       359.910
# 132    22.20  15.283000     116.740  1305.544     381.197       362.447
# 146    15.80  14.050000     108.104  1292.741     262.802       361.141
# 147    16.50  11.958000     108.493  1282.021     323.560       360.958
# 174    13.48  13.633000     105.911  1232.975     169.841       360.093
# 175    14.39  11.642000     104.759  1244.014     198.128       361.416
# 176    18.04  11.875000     102.457  1242.285     223.763       356.604
# 199    16.90  14.183000     101.469  1161.818     221.039       369.503
# ...

# %%
#replace BF_CMratio outliers with mean values
df.BF_CMratio[(df.BF_CMratio>100)]=df.BF_CMratio.median()

# %%
df[(df.BlowFlow<1100)]
# Out:
#      Y_Kappa   ChipRate  BF_CMratio  BlowFlow  ChipLevel4  T_upperExt_2  \
# 31     16.10  16.292000   68.645000  1094.883     245.962       344.478
# 182    23.83  14.227000   87.464456     0.000     220.074       352.981
# 200    17.60  14.855000   93.860000  1084.083     303.017       372.524
# 201    21.40  14.956000   87.255000  1092.148     284.218       368.547
# 202    15.88  14.517000   85.569000  1097.421       0.000       367.651
# 203    17.51  12.825000   92.165000  1094.463       0.000       370.845
# 204    16.50  11.875000   97.958000  1084.886       0.000       380.662
# 278    21.19  13.833000   88.977000  1012.859     294.721       351.813
# 279    21.27  11.383000   84.165000   981.920     342.858       352.315
# 280    23.74  11.667000   88.130000   990.724     349.088       349.697
# 281    24.41  11.242000   80.458000   954.092     365.583       342.403
# 282    21.18  11.858000   91.363000  1001.950     301.468       342.525
# ...

# %%
#replace BlowFlow outliers with mean values
df.BlowFlow[(df.BlowFlow<1100)]=df.BlowFlow.mean()

# %%
df[(df.ChipLevel4>90)]
# Out:
#      Y_Kappa   ChipRate  BF_CMratio  BlowFlow  ChipLevel4  T_upperExt_2  \
# 0      23.10  16.520000      87.057  1177.607     169.805       358.282
# 1      27.60  16.810000      79.022  1328.360     341.327       351.050
# 2      23.19  16.709000      79.562  1329.407     239.161       350.022
# 3      23.60  16.478000      81.011  1334.877     213.527       350.938
# 4      22.90  15.618000      93.244  1334.168     243.131       351.640
# ..       ...        ...         ...       ...         ...           ...
# 298    20.90  15.167000      84.640  1283.706     339.440       354.803
# 299    24.98  14.347937      85.034  1278.345     368.564       357.723
# 300    21.00  14.347937      88.013  1307.722     278.842       357.438
# 301    21.40  14.347937      85.490  1255.986     273.484       361.365
# 307    20.89  14.308000      94.172  1327.832     251.120       351.263
#
#      T_lowerExt_2    UCZAA  WhiteFlow_4  AAWhiteSt_4  ...  SteamFlow_4  \
# ...

# %%
#replace ChipLevel4 outliers with mean values
df.ChipLevel4[(df.ChipLevel4>90)]=df.ChipLevel4.mean()

# %%
df[(df.T_upperExt_2<375)]
# Out:
#      Y_Kappa   ChipRate  BF_CMratio  BlowFlow  ChipLevel4  T_upperExt_2  \
# 0      23.10  16.520000      87.057  1177.607  259.362002       358.282
# 1      27.60  16.810000      79.022  1328.360  259.362002       351.050
# 2      23.19  16.709000      79.562  1329.407  259.362002       350.022
# 3      23.60  16.478000      81.011  1334.877  259.362002       350.938
# 4      22.90  15.618000      93.244  1334.168  259.362002       351.640
# ..       ...        ...         ...       ...         ...           ...
# 298    20.90  15.167000      84.640  1283.706  259.362002       354.803
# 299    24.98  14.347937      85.034  1278.345  259.362002       357.723
# 300    21.00  14.347937      88.013  1307.722  259.362002       357.438
# 301    21.40  14.347937      85.490  1255.986  259.362002       361.365
# 307    20.89  14.308000      94.172  1327.832  259.362002       351.263
#
#      T_lowerExt_2    UCZAA  WhiteFlow_4  AAWhiteSt_4  ...  SteamFlow_4  \
# ...

# %%
#replace T_upperExt_2 outliers with mean values
df.T_upperExt_2[(df.T_upperExt_2>135)]=df.T_upperExt_2.median()

# %%
df[(df.T_lowerExt_2>305)]
# Out:
#      Y_Kappa   ChipRate  BF_CMratio  BlowFlow  ChipLevel4  T_upperExt_2  \
# 0      23.10  16.520000      87.057  1177.607  259.362002       357.163
# 1      27.60  16.810000      79.022  1328.360  259.362002       357.163
# 2      23.19  16.709000      79.562  1329.407  259.362002       357.163
# 3      23.60  16.478000      81.011  1334.877  259.362002       357.163
# 4      22.90  15.618000      93.244  1334.168  259.362002       357.163
# ..       ...        ...         ...       ...         ...           ...
# 298    20.90  15.167000      84.640  1283.706  259.362002       357.163
# 299    24.98  14.347937      85.034  1278.345  259.362002       357.163
# 300    21.00  14.347937      88.013  1307.722  259.362002       357.163
# 301    21.40  14.347937      85.490  1255.986  259.362002       357.163
# 307    20.89  14.308000      94.172  1327.832  259.362002       357.163
#
#      T_lowerExt_2    UCZAA  WhiteFlow_4  AAWhiteSt_4  ...  SteamFlow_4  \
# ...

# %%
#replace T_lowerExt_2 outliers with mean values
df.T_lowerExt_2[(df.T_lowerExt_2>305)]=df.T_lowerExt_2.mean()

# %%
df[(df.UCZAA<13)]
# Out:
#      Y_Kappa   ChipRate  BF_CMratio  BlowFlow  ChipLevel4  T_upperExt_2  \
# 0      23.10  16.520000      87.057  1177.607  259.362002       357.163
# 1      27.60  16.810000      79.022  1328.360  259.362002       357.163
# 2      23.19  16.709000      79.562  1329.407  259.362002       357.163
# 3      23.60  16.478000      81.011  1334.877  259.362002       357.163
# 4      22.90  15.618000      93.244  1334.168  259.362002       357.163
# ..       ...        ...         ...       ...         ...           ...
# 298    20.90  15.167000      84.640  1283.706  259.362002       357.163
# 299    24.98  14.347937      85.034  1278.345  259.362002       357.163
# 300    21.00  14.347937      88.013  1307.722  259.362002       357.163
# 301    21.40  14.347937      85.490  1255.986  259.362002       357.163
# 307    20.89  14.308000      94.172  1327.832  259.362002       357.163
#
#      T_lowerExt_2    UCZAA  WhiteFlow_4  AAWhiteSt_4  ...  SteamFlow_4  \
# ...

# %%
#replace UCZAA outliers with mean values
df.UCZAA[(df.UCZAA>13)]=df.UCZAA.mean()

# %%
df[(df.AAWhiteSt_4<6.0)]
# Out:
#      Y_Kappa  ChipRate  BF_CMratio     BlowFlow  ChipLevel4  T_upperExt_2  \
# 194    23.12    13.558      85.718  1162.192000  259.362002       357.163
# 196    17.81    14.375      83.036  1193.646000  259.362002       357.163
# 197    16.10    13.442      95.320  1206.594000  259.362002       357.163
# 199    16.90    14.183      87.057  1161.818000  259.362002       357.163
# 202    15.88    14.517      85.569  1235.636628    0.000000       357.163
#
#      T_lowerExt_2    UCZAA  WhiteFlow_4  AAWhiteSt_4  ...  SteamFlow_4  \
# 194    324.010815  1.69100      549.611        5.919  ...       63.877
# 196    324.010815  1.71000      642.588        5.890  ...       72.265
# 197    324.010815  1.49201      630.635        5.983  ...       65.347
# 199    324.010815  1.52200      607.340        5.940  ...       72.488
# 202    324.010815  1.49201      583.282        5.950  ...       72.254
#
#      Lower_HeatT_3  Upper_HeatT_3  ChipMass_4  WeakLiquorF  BlackFlow_2  \
# ...

# %%
#replace AAWhiteSt_4 outliers with mean values
df.AAWhiteSt_4[(df.AAWhiteSt_4>6.0)]=df.AAWhiteSt_4.mean()

# %%
df[(df.SteamFlow_4<52)]
# Out:
#      Y_Kappa  ChipRate  BF_CMratio     BlowFlow  ChipLevel4  T_upperExt_2  \
# 40     27.10    13.558   83.117000  1175.417000  259.362002       357.163
# 208    17.75    11.283   87.464456  1237.837614   41.607000       357.163
# 287    21.20    11.292   92.194000  1235.636628  259.362002       357.163
#
#      T_lowerExt_2  UCZAA  WhiteFlow_4  AAWhiteSt_4  ...  SteamFlow_4  \
# 40     324.010815  1.360      480.184     6.141794  ...       48.568
# 208    324.010815  1.658      467.265     6.141794  ...       50.663
# 287    297.247000  1.457      405.111     6.141794  ...       51.192
#
#      Lower_HeatT_3  Upper_HeatT_3  ChipMass_4  WeakLiquorF  BlackFlow_2  \
# 40       318.22800     294.850000     131.537      744.659      996.046
# 208      325.56782     300.525699     128.396      836.060     1195.731
# 287      328.28900     305.824000     113.922      838.094     1292.599
#
#      WeakWashF  SteamHeatF_3  T_Top_Chips_4  SulphidityL_4
# ...

# %%
#replace SteamFlow_4 outliers with mean values
df.SteamFlow_4[(df.SteamFlow_4>52)]=df.SteamFlow_4.mean()

# %%
df[(df.ChipMass_4<130)]
# Out:
#      Y_Kappa   ChipRate  BF_CMratio     BlowFlow  ChipLevel4  T_upperExt_2  \
# 208    17.75  11.283000   87.464456  1237.837614   41.607000       357.163
# 210    19.20  14.183000   85.406000  1211.339000  259.362002       357.163
# 286    19.53  11.245000   92.564000  1235.636628  259.362002       357.163
# 287    21.20  11.292000   92.194000  1235.636628  259.362002       357.163
# 288    22.10  14.338793   97.752000  1235.636628  259.362002       357.163
# 290    19.90  11.333000   87.405000  1235.636628  259.362002       357.163
# 291    21.00  11.825000   90.949000  1235.636628  259.362002       357.163
# 292    22.00  11.858000   93.199000  1171.206000  259.362002       357.163
# 293    19.50  12.567000   96.937000  1204.438000  259.362002       357.163
#
#      T_lowerExt_2    UCZAA  WhiteFlow_4  AAWhiteSt_4  ...  SteamFlow_4  \
# 208    324.010815  1.65800      467.265     6.141794  ...    50.663000
# 210    324.010815  1.47800      562.029     6.141794  ...    66.834014
# ...

# %%
#replace ChipMass_4 outliers with mean values
df.ChipMass_4[(df.ChipMass_4>30)]=df.ChipMass_4.mean()

# %%
df[(df.SteamHeatF_3<40)]
# Out:
#      Y_Kappa   ChipRate  BF_CMratio     BlowFlow  ChipLevel4  T_upperExt_2  \
# 38     18.45  12.917000      84.483  1175.728000  259.362002       357.163
# 39     24.30  13.917000      87.835  1190.889000  259.362002       357.163
# 63     24.70  16.183000      72.611  1231.362000  259.362002       357.163
# 281    24.41  11.242000      80.458  1235.636628  259.362002       357.163
# 286    19.53  11.245000      92.564  1235.636628  259.362002       357.163
# 287    21.20  11.292000      92.194  1235.636628  259.362002       357.163
# 288    22.10  14.338793      97.752  1235.636628  259.362002       357.163
# 291    21.00  11.825000      90.949  1235.636628  259.362002       357.163
#
#      T_lowerExt_2    UCZAA  WhiteFlow_4  AAWhiteSt_4  ...  SteamFlow_4  \
# 38     324.010815  1.22900      561.564     6.141794  ...    66.834014
# 39     324.010815  1.34600      492.543     6.141794  ...    66.834014
# 63     324.010815  1.45500      564.870     6.141794  ...    66.834014
# ...

# %%
#replace SteamHeatF_3 outliers with mean values
df.SteamHeatF_3[(df.SteamHeatF_3>40)]=df.SteamHeatF_3.mean()

# %%
df[(df.SulphidityL_4<30.2)]
# Out:
#      Y_Kappa   ChipRate  BF_CMratio     BlowFlow  ChipLevel4  T_upperExt_2  \
# 1      27.60  16.810000   79.022000  1328.360000  259.362002       357.163
# 3      23.60  16.478000   81.011000  1334.877000  259.362002       357.163
# 4      22.90  15.618000   93.244000  1334.168000  259.362002       357.163
# 7      22.65  14.100000   91.887000  1307.852000  259.362002       357.163
# 9      24.70  13.850000   96.208000  1334.892000  259.362002       357.163
# 11     24.40  14.117000   85.998000  1330.104000  259.362002       357.163
# 13     27.20  16.083000   82.839000  1332.331000  259.362002       357.163
# 20     20.30  12.058000   89.523000  1180.205000  259.362002       357.163
# 22     23.00  14.067000   88.383000  1191.691000  259.362002       357.163
# 24     21.40  12.875000   92.564000  1191.757000  259.362002       357.163
# 26     18.90  12.542000   94.741000  1188.212000  259.362002       357.163
# ...

# %%
#replace SulphidityL_4 outliers with mean values
df.SulphidityL_4[(df.SulphidityL_4>30.2)]=df.SulphidityL_4.mean()

# %%
#after outlier treatment
#outliers
box=df[['Y_Kappa',
 'ChipRate',
 'BF_CMratio',
 'BlowFlow',
 'ChipLevel4',
 'T_upperExt_2',
 'T_lowerExt_2',
 'UCZAA',
 'WhiteFlow_4',
 'AAWhiteSt_4',
 'AA_Wood_4',
 'ChipMoisture_4',
 'SteamFlow_4',
 'Lower_HeatT_3',
 'Upper_HeatT_3',
 'ChipMass_4',
 'WeakLiquorF',
 'BlackFlow_2',
 'WeakWashF',
 'SteamHeatF_3',
 'T_Top_Chips_4',
 'SulphidityL_4']]
plt.figure(figsize=(50,30), facecolor='white')#to sey canvas size
plotnumber = 1#counter

for column in box:#acc
    if plotnumber<=25 : # as there are 9 columns in the data
        ax = plt.subplot(25,1,plotnumber)#plotting 6 graphs
        sns.boxplot(x=box[column])#boxplot to check for outlier
        plt.xlabel(column,fontsize=10)#assign name to x-axis and set font-20
     
    plotnumber+=1#counter increment 
plt.tight_layout()#to show plot

# %%
#scalar Transformation
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
df[['Y_Kappa',
 'ChipRate',
 'BF_CMratio',
 'BlowFlow',
 'ChipLevel4',
 'T_upperExt_2',
 'T_lowerExt_2',
 'UCZAA',
 'WhiteFlow_4',
 'AAWhiteSt_4',
 'AA_Wood_4',
 'ChipMoisture_4',
 'SteamFlow_4',
 'Lower_HeatT_3',
 'Upper_HeatT_3',
 'ChipMass_4',
 'WeakLiquorF',
 'BlackFlow_2',
 'WeakWashF',
 'SteamHeatF_3',
 'T_Top_Chips_4',
 'SulphidityL_4']]=sc.fit_transform(df[['Y_Kappa',
 'ChipRate',
 'BF_CMratio',
 'BlowFlow',
 'ChipLevel4',
 'T_upperExt_2',
 'T_lowerExt_2',
 'UCZAA',
 'WhiteFlow_4',
 'AAWhiteSt_4',
 'AA_Wood_4',
 'ChipMoisture_4',
 'SteamFlow_4',
 'Lower_HeatT_3',
 'Upper_HeatT_3',
 'ChipMass_4',
 'WeakLiquorF',
 'BlackFlow_2',
 'WeakWashF',
 'SteamHeatF_3',
 'T_Top_Chips_4',
 'SulphidityL_4']])

# %%
df
# Out:
#       Y_Kappa  ChipRate  BF_CMratio  BlowFlow  ChipLevel4  T_upperExt_2  \
# 0    0.847817  1.532176    0.109893 -1.728319    0.227152  5.684342e-14
# 1    2.354962  1.743990   -1.203290  1.738653    0.227152  5.684342e-14
# 2    0.877960  1.670220   -1.115036  1.762732    0.227152  5.684342e-14
# 3    1.015278  1.501500   -0.878222  1.888529    0.227152  5.684342e-14
# 4    0.780833  0.873363    1.121052  1.872224    0.227152  5.684342e-14
# ..        ...       ...         ...       ...         ...           ...
# 298  0.110991  0.543957   -0.285124  0.711714    0.227152  5.684342e-14
# 299  1.477469 -0.054280   -0.220732  0.588423    0.227152  5.684342e-14
# 300  0.144483 -0.054280    0.266135  1.264027    0.227152  5.684342e-14
# 301  0.278452 -0.054280   -0.146206  0.074218    0.227152  5.684342e-14
# 307  0.107642 -0.083450    1.272717  1.726511    0.227152  5.684342e-14
#
#      T_lowerExt_2     UCZAA  WhiteFlow_4  AAWhiteSt_4  ...  SteamFlow_4  \
# ...
